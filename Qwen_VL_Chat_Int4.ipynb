# %% [markdown]
# <a href="https://colab.research.google.com/github/musatea/tattoo-identification-atcns/blob/main/Qwen_VL_Chat_Int4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers==4.32.0 accelerate tiktoken einops
# !pip install -q transformers_stream_generator==0.0.4
# !pip install -q scipy torchvision pillow tensorboard matplotlib
# !pip install -q optimum
# !pip install -q auto-gptq
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 20.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 31.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 64.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 74.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 54.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.0/417.0 kB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 12.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 15.6 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
torch.manual_seed(1234)

# Note: The default behavior now has injection attack prevention off.
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen-VL-Chat-Int4", trust_remote_code=True)

# use cuda device
model = AutoModelForCausalLM.from_pretrained("Qwen/Qwen-VL-Chat-Int4", device_map="cuda", trust_remote_code=True).eval()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# tokenization_qwen.py:   0%|          | 0.00/21.9k [00:00<?, ?B/s]
# ...

# %%
img='https://drive.google.com/uc?export=view&id=1Yq6Djt-KbhpoJXUnVSLQtfmM5DN5wR-y'

# %%
# 1st dialogue turn
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'What specific symbols are present in this tattoo? '},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# The tattoo features a barbed wire design on the man's forehead.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Is this tattoo from mafia or gang?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# The tattoo of barbed wire on the forehead is often associated with gang culture, but it's important to note that not all people with such tattoos belong to a gang or mafia. The tattoo could be a personal choice or a representation of a specific event or experience in the individual's life. Without more context, it's impossible to determine the true meaning or purpose of the tattoo.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'What does this symbol represent in the context of Mafia or gang affiliations?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# The symbol of a barbed wire tattoo on a man's forehead, as seen in the image, is commonly associated with Mafia or gang affiliations. It is known as the "Cicero" tattoo, named after the Roman statesman and orator Marcus Tullius Cicero. The barbed wire tattoo represents the idea of being "caged" or trapped, which is a common theme in organized crime and criminal activities. It is often worn by members of criminal organizations to convey their commitment to their criminal lifestyle and their perceived immunity from law enforcement.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Is this a tattoo from a member of the Bratva mafia group? '},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# I think it can be related to Bratva.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Where on the body is the tattoo located? '},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# The tattoo is located on the forehead of the man.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Is there any significance to the placement of this tattoo?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# The placement of the tattoo on the man's forehead is significant as it symbolizes his past experience as a prisoner. In the concentration camps, prisoners were often forced to have a barbed wire tattoo on their foreheads as a form of identification. This tattoo served as a reminder of their captivity and served as a constant visual reminder of their past experiences. By having this tattoo on his forehead, the man is showing his resilience and strength in overcoming the traumatic experience of being a prisoner.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Which is the gang or mafia that could use this tattoo?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# The tattoo of barbed wire on the forehead is often associated with Russian mafia groups, particularly the Bratva. The Bratva is a criminal organization that originated in the Soviet Union and has since spread to other countries, including Russia. They are known for their violent and chaotic behavior, and the tattoo is a way for members to show their affiliation and commitment to the group.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Does this photo include animal as the symbol in the tattoo?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# No, the photo does not include any animals. The symbol in the tattoo is barbed wire.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Does this photo include barbed wire tattoo?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# Yes, the photo includes a barbed wire tattoo on the forehead of a man.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'Is this tattoo colored or not?'},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# This tattoo is not colored, it is a black and white tattoo.

# %%
query = tokenizer.from_list_format([
    {'image': img},
    {'text': 'What is the color of the tattoo? '},
])
response, history = model.chat(tokenizer, query=query, history=None)
print(response)
# Out:
# The tattoo is black.
